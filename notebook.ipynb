# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
abs_path = os.path.dirname(os.path.abspath(sys.argv[0]))

# %%
event = pd.read_csv(os.path.join(abs_path, "data", "events.csv"))
# category = pd.read_csv(cattpath)
# props = pd.concat([pd.read_csv(ip1path), pd.read_csv(ip2path)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 event = pd.read_csv(os.path.join(abs_path, "data", "events.csv"))
#       2 # category = pd.read_csv(cattpath)
#       3 # props = pd.concat([pd.read_csv(ip1path), pd.read_csv(ip2path)])
#
# ...

# %%
print('events----------------------- \n\n\n', event.info())
print('categories------------------- \n\n\n', category.info())
print('item_properties-------------- \n\n\n', props.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2756101 entries, 0 to 2756100
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      int64
#  1   visitorid      int64
#  2   event          object
#  3   itemid         int64
#  4   transactionid  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 105.1+ MB
# events-----------------------
#
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categoryid  1669 non-null   int64
#  1   parentid    1644 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 26.2 KB
# categories-------------------
#
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# Index: 20275902 entries, 0 to 9275902
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
# ...

# %%
props.head()
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513

# %%
props['property'].value_counts().head(20)
# Out:
# property
# 888           3000398
# 790           1790516
# available     1503639
# categoryid     788214
# 6              631471
# 283            597419
# 776            574220
# 678            481966
# 364            476486
# 202            448938
# 839            417239
# 917            417227
# 764            417053
# 159            417053
# 112            417053
# 227            347492
# 698            289849
# 451            264416
# 663            240813
# 962            239372
# Name: count, dtype: int64

# %%
latest_props = props.sort_values('timestamp').groupby(['itemid', 'property']).last().reset_index()

# %%
event.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
event.merge(event, on="visitorid")

# %%
p = props.head(20)
print(p)

# %%
# p = p.reset_index()
print(p)

# %%
event
